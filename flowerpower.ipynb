# %% [markdown]
# # Flower Power
# Ok, time to important the data

# %%
from sklearn.datasets import load_iris
import numpy as np

# setting as_frame to True makes data and target as pandas DataFrame/Series
# returned value is still Bunch
iris = load_iris(as_frame=True)

# %%
# Describe the dataset
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris.target
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
import pandas as pd
#import data as a pandas data frame
iris_data = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_data['target'] = iris.target
iris_data['target_names'] = iris.target_names[iris.target]

# %%
iris_data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target target_names
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa
# 3       0       setosa
# 4       0       setosa

# %%
iris_data.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target', 'target_names'],
#       dtype='object')

# %%
iris_data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target target_names
# ...

# %%
iris_data.groupby('target_names').size()
# Out:
# target_names
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
iris_data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# We can use SeaBorn to visualize the data

# %%
import seaborn as sns
sns.pairplot(iris_data, hue='target_names')

# %%
x=iris.data
y=iris.target

# %% [markdown]
# We need to split the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

# %% [markdown]
# Now we can choose the model

# %%
y_train.dtype
x_train.dtype
# Out:
# dtype('O')

# %%
from sklearn import tree
classifier=tree.DecisionTreeClassifier()
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.svm import SVC
svn = SVC()
svn.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/samuel/code/pythonstuff/mlstuff/flowerpower.ipynb Cell 21 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bliviu/home/samuel/code/pythonstuff/mlstuff/flowerpower.ipynb#X34sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from sklearn.svm import SVC
#       <a href='vscode-notebook-cell://ssh-remote%2Bliviu/home/samuel/code/pythonstuff/mlstuff/flowerpower.ipynb#X34sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> svn = SVC()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bliviu/home/samuel/code/pythonstuff/mlstuff/flowerpower.ipynb#X34sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> svn.fit(X_train, y_train)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
# ...

# %% [markdown]
# Let us check the results:

# %%
predictions=classifier.predict(x_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 0.92
